# %%
import os, sys
script_dir = os.getcwd()
module_path = script_dir
for _ in range(1):
    module_path = os.path.abspath(os.path.join(module_path, '../'))
    if module_path not in sys.path:
        sys.path.insert(0,module_path)

from src import decode_moddeling, prefill_moddeling

import pandas as pd
from plotnine import *
import plotnine as p9
from src.system import System
import pandas as pd
from src.analye_model import *
import plotly.graph_objects as go
import plotly.express as px

# %%
model_df, summary_table = decode_moddeling(model = 'mixtral_7x8', batch_size = 1, Bb = 1 ,
                            input_tokens = 1024, output_tokens = 256, model_profilling=True,
                            tensor_parallel = 1, pipeline_parallel = 1, debug=True) 
display(model_df)
display(summary_table)
# Out:
# /Users/abambhaniya3/GenZ/src/LLM_inference/llm_decode.py:108: UserWarning: All params would not fit on chip. System Memory Cap:40.0 GB , Weights : 86.5 GB, KV Cache:0.15625
#        Op Type                 Dimension Op Intensity Num ops (MFLOP)  \
# 0         GEMM        [1, 6144, 1, 4096]      0.99959        50.33165
# 1    Logit_MQA  [1, 32, 1, 1024, 128, 8]      3.86415         8.38861
# 2    Logit_MQA   [1, 32, 1, 256, 128, 8]      3.82090         2.09715
# 3   Attend_MQA  [1, 32, 1, 1024, 128, 8]      3.86415         8.38861
# 4   Attend_MQA   [1, 32, 1, 256, 128, 8]      3.82090         2.09715
# 5         GEMM        [1, 4096, 1, 4096]      0.99951        33.55443
# 6         GEMM       [1, 28672, 1, 4096]      0.99972       234.88102
# 7         GEMM       [1, 86016, 0, 4096]      0.00000         0.00000
# 8         GEMM       [1, 28672, 1, 4096]      0.99972       234.88102
# 9         GEMM       [1, 86016, 0, 4096]      0.00000         0.00000
# 10        GEMM       [1, 4096, 1, 28672]      0.99972       234.88102
# 11        GEMM       [1, 4096, 0, 86016]      0.00000         0.00000
#
#    Input_a (MB) Input_w (MB) Output (MB) Total Data (MB)
# 0       0.00781     48.00000     0.01172        48.01953
# 1       0.00781      2.00000     0.06250         2.07031
# 2       0.00781      0.50000     0.01562         0.52344
# 3       0.06250      2.00000     0.00781         2.07031
# 4       0.01562      0.50000     0.00781         0.52344
# 5       0.00781     32.00000     0.00781        32.01562
# 6       0.00781    224.00000     0.05469       224.06250
# 7       0.00000    672.00000     0.00000       672.00000
# 8       0.00781    224.00000     0.05469       224.06250
# 9       0.00000    672.00000     0.00000       672.00000
# 10      0.05469    224.00000     0.00781       224.06250
# 11      0.00000    672.00000     0.00000       672.00000
#    MACs (MFLOP)  Total Data (MB)  Model Weights (MB)  Unused Weights (MB)  \
# 0   25904.02150      88749.12500         88576.00000          64512.00000
#
#    KV Cache (MB)  AR data (MB)  Pipe data  (MB)
# 0      160.00000       0.50000          0.00000

# %%
for model in ['mixtral_7x8']:
    model_df, summary_table = prefill_moddeling(model = model, batch_size = 1,
                            input_tokens = 1024, output_tokens = 0, model_profilling=True,
                            tensor_parallel = 1, pipeline_parallel = 1) 
    print(model)
    display(model_df)
    display(summary_table)
# Out:
# mixtral_7x8
# /Users/abambhaniya3/GenZ/src/LLM_inference/llm_prefill.py:106: UserWarning: All params would not fit on chip. System Memory Cap:40.0 GB , Weights : 86.5 GB, KV Cache:0.125
#       Op Type                    Dimension Op Intensity Num ops (MFLOP)  \
# 0        GEMM        [1, 6144, 1024, 4096]    722.82353     51539.60755
# 1   Logit_MQA  [1, 32, 1024, 1024, 128, 8]    110.70270      8589.93459
# 2  Attend_MQA  [1, 32, 1024, 1024, 128, 8]    110.70270      8589.93459
# 3        GEMM        [1, 4096, 1024, 4096]    682.66667     34359.73837
# 4        GEMM       [1, 114688, 256, 4096]    240.43606    240518.16858
# 5        GEMM       [1, 114688, 256, 4096]    240.43606    240518.16858
# 6        GEMM       [1, 4096, 256, 114688]    240.43606    240518.16858
#
#   Input_a (MB) Input_w (MB) Output (MB) Total Data (MB)
# 0      8.00000     48.00000    12.00000        68.00000
# 1      8.00000      2.00000    64.00000        74.00000
# 2     64.00000      2.00000     8.00000        74.00000
# 3      8.00000     32.00000     8.00000        48.00000
# 4      2.00000    896.00000    56.00000       954.00000
# 5      2.00000    896.00000    56.00000       954.00000
# 6     56.00000    896.00000     2.00000       954.00000
#     MACs (MFLOP)  Total Data (MB)  Model Weights (MB)  Unused Weights (MB)  \
# 0 26388279.06662     100032.00000         88576.00000                    0
#
#    KV Cache (MB)  AR data (MB)  Pipe data  (MB)
# 0      128.00000     512.00000          0.00000

# %%
decode_moddeling(model = 'mixtral_7x8', batch_size = 1, Bb = 1 ,
                            input_tokens = 1024, output_tokens = 256, model_profilling=False,
                            tensor_parallel = 4, pipeline_parallel = 1, debug=True)
# Out:
# <style type="text/css">
# #T_31926_row0_col2, #T_31926_row5_col2, #T_31926_row6_col2, #T_31926_row8_col2, #T_31926_row10_col2 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_31926_row0_col4, #T_31926_row0_col6, #T_31926_row1_col4, #T_31926_row2_col5, #T_31926_row2_col6, #T_31926_row3_col6, #T_31926_row4_col4, #T_31926_row4_col5, #T_31926_row5_col4, #T_31926_row5_col6, #T_31926_row6_col4, #T_31926_row6_col6, #T_31926_row7_col4, #T_31926_row7_col6, #T_31926_row8_col4, #T_31926_row8_col6, #T_31926_row9_col4, #T_31926_row9_col6, #T_31926_row10_col4, #T_31926_row10_col6, #T_31926_row11_col4, #T_31926_row11_col6 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_31926_row0_col5, #T_31926_row1_col5, #T_31926_row2_col4, #T_31926_row3_col5, #T_31926_row4_col6, #T_31926_row5_col5, #T_31926_row6_col5, #T_31926_row7_col5, #T_31926_row8_col5, #T_31926_row9_col5, #T_31926_row10_col5, #T_31926_row11_col5 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_31926_row0_col7 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_31926_row0_col9, #T_31926_row1_col9, #T_31926_row2_col8, #T_31926_row2_col9, #T_31926_row3_col9, #T_31926_row4_col8, #T_31926_row4_col9, #T_31926_row5_col9, #T_31926_row6_col9, #T_31926_row7_col8, #T_31926_row7_col9, #T_31926_row8_col9, #T_31926_row9_col8, #T_31926_row9_col9, #T_31926_row10_col9, #T_31926_row11_col8, #T_31926_row11_col9 {
#   background-color: green;
# }
# #T_31926_row0_col10, #T_31926_row1_col10, #T_31926_row2_col10, #T_31926_row3_col10, #T_31926_row4_col10, #T_31926_row5_col10, #T_31926_row6_col10, #T_31926_row7_col10, #T_31926_row8_col10, #T_31926_row9_col10, #T_31926_row10_col10, #T_31926_row11_col10 {
#   color: red;
# }
# #T_31926_row0_col12 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_31926_row1_col2, #T_31926_row3_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_31926_row1_col6, #T_31926_row3_col4 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_31926_row1_col7, #T_31926_row2_col7, #T_31926_row2_col12, #T_31926_row3_col7, #T_31926_row4_col7, #T_31926_row4_col12, #T_31926_row7_col12, #T_31926_row9_col12, #T_31926_row11_col12 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_31926_row1_col12, #T_31926_row3_col12 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_31926_row2_col2, #T_31926_row4_col2, #T_31926_row7_col2, #T_31926_row9_col2, #T_31926_row11_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_31926_row5_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_31926_row5_col12 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_31926_row6_col7, #T_31926_row8_col7, #T_31926_row10_col7 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_31926_row6_col12, #T_31926_row7_col7, #T_31926_row8_col12, #T_31926_row9_col7, #T_31926_row10_col12, #T_31926_row11_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_31926">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31926_level0_col0" class="col_heading level0 col0" >Op Type</th>
#       <th id="T_31926_level0_col1" class="col_heading level0 col1" >Dimension</th>
#       <th id="T_31926_level0_col2" class="col_heading level0 col2" >Op Intensity</th>
#       <th id="T_31926_level0_col3" class="col_heading level0 col3" >Num ops (MFLOP)</th>
#       <th id="T_31926_level0_col4" class="col_heading level0 col4" >Input_a (MB)</th>
#       <th id="T_31926_level0_col5" class="col_heading level0 col5" >Input_w (MB)</th>
#       <th id="T_31926_level0_col6" class="col_heading level0 col6" >Output (MB)</th>
#       <th id="T_31926_level0_col7" class="col_heading level0 col7" >Total Data (MB)</th>
#       <th id="T_31926_level0_col8" class="col_heading level0 col8" >Compute time (msec)</th>
#       <th id="T_31926_level0_col9" class="col_heading level0 col9" >Memory time (msec)</th>
#       <th id="T_31926_level0_col10" class="col_heading level0 col10" >Bound</th>
#       <th id="T_31926_level0_col11" class="col_heading level0 col11" >C/M ratio</th>
#       <th id="T_31926_level0_col12" class="col_heading level0 col12" >Cycles</th>
#       <th id="T_31926_level0_col13" class="col_heading level0 col13" >% of total time</th>
#       <th id="T_31926_level0_col14" class="col_heading level0 col14" >Throughput (Tflops)</th>
#       <th id="T_31926_level0_col15" class="col_heading level0 col15" >Compute cycle</th>
#       <th id="T_31926_level0_col16" class="col_heading level0 col16" >Memory cycle</th>
#       <th id="T_31926_level0_col17" class="col_heading level0 col17" >Latency (msec)</th>
#       <th id="T_31926_level0_col18" class="col_heading level0 col18" >C Effcy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31926_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31926_row0_col0" class="data row0 col0" >GEMM</td>
#       <td id="T_31926_row0_col1" class="data row0 col1" >[   1 1536    1 4096]</td>
#       <td id="T_31926_row0_col2" class="data row0 col2" >0.999106</td>
#       <td id="T_31926_row0_col3" class="data row0 col3" >12.582912</td>
#       <td id="T_31926_row0_col4" class="data row0 col4" >0.007812</td>
#       <td id="T_31926_row0_col5" class="data row0 col5" >12.000000</td>
#       <td id="T_31926_row0_col6" class="data row0 col6" >0.002930</td>
#       <td id="T_31926_row0_col7" class="data row0 col7" >12.010742</td>
#       <td id="T_31926_row0_col8" class="data row0 col8" >0.000040</td>
#       <td id="T_31926_row0_col9" class="data row0 col9" >0.007331</td>
#       <td id="T_31926_row0_col10" class="data row0 col10" >M</td>
#       <td id="T_31926_row0_col11" class="data row0 col11" >0.005501</td>
#       <td id="T_31926_row0_col12" class="data row0 col12" >7330.775261</td>
#       <td id="T_31926_row0_col13" class="data row0 col13" >6.351810</td>
#       <td id="T_31926_row0_col14" class="data row0 col14" >1.716450</td>
#       <td id="T_31926_row0_col15" class="data row0 col15" >40.329846</td>
#       <td id="T_31926_row0_col16" class="data row0 col16" >7330.775261</td>
#       <td id="T_31926_row0_col17" class="data row0 col17" >0.007331</td>
#       <td id="T_31926_row0_col18" class="data row0 col18" >1</td>
#     </tr>
#     <tr>
#       <th id="T_31926_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31926_row1_col0" class="data row1 col0" >Logit_MQA</td>
#       <td id="T_31926_row1_col1" class="data row1 col1" >[   1    8    1 1024  128    2]</td>
#       <td id="T_31926_row1_col2" class="data row1 col2" >3.864151</td>
#       <td id="T_31926_row1_col3" class="data row1 col3" >2.097152</td>
#       <td id="T_31926_row1_col4" class="data row1 col4" >0.001953</td>
#       <td id="T_31926_row1_col5" class="data row1 col5" >0.500000</td>
#       <td id="T_31926_row1_col6" class="data row1 col6" >0.015625</td>
#       <td id="T_31926_row1_col7" class="data row1 col7" >0.517578</td>
#       <td id="T_31926_row1_col8" class="data row1 col8" >0.000007</td>
#       <td id="T_31926_row1_col9" class="data row1 col9" >0.000307</td>
#       <td id="T_31926_row1_col10" class="data row1 col10" >M</td>
#       <td id="T_31926_row1_col11" class="data row1 col11" >0.021879</td>
#       <td id="T_31926_row1_col12" class="data row1 col12" >307.215585</td>
#       <td id="T_31926_row1_col13" class="data row1 col13" >0.266189</td>
#       <td id="T_31926_row1_col14" class="data row1 col14" >6.826320</td>
#       <td id="T_31926_row1_col15" class="data row1 col15" >6.721641</td>
#       <td id="T_31926_row1_col16" class="data row1 col16" >307.215585</td>
#       <td id="T_31926_row1_col17" class="data row1 col17" >0.000307</td>
#       <td id="T_31926_row1_col18" class="data row1 col18" >1</td>
#     </tr>
#     <tr>
#       <th id="T_31926_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31926_row2_col0" class="data row2 col0" >Logit_MQA</td>
#       <td id="T_31926_row2_col1" class="data row2 col1" >[  1   8   1   0 128   2]</td>
#       <td id="T_31926_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_31926_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_31926_row2_col4" class="data row2 col4" >0.0019
#    MACs (MFLOP)  Total Data (MB)  Total Weights (MB)  Parameters  (MB)  \
# 0     201.32659        693.12402           692.00000         692.00000
#
#    On-chip Memory Footprint (MB)  Latency (msec)       Cycles
# 0                      168.00000         0.11541 115412.38096
# <style type="text/css">
# #T_6ea96_row0_col2, #T_6ea96_row5_col2, #T_6ea96_row6_col2, #T_6ea96_row8_col2, #T_6ea96_row10_col2 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_6ea96_row0_col4, #T_6ea96_row0_col6, #T_6ea96_row1_col4, #T_6ea96_row2_col4, #T_6ea96_row3_col6, #T_6ea96_row4_col6, #T_6ea96_row5_col4, #T_6ea96_row5_col6, #T_6ea96_row6_col4, #T_6ea96_row6_col6, #T_6ea96_row7_col4, #T_6ea96_row7_col6, #T_6ea96_row8_col4, #T_6ea96_row8_col6, #T_6ea96_row9_col4, #T_6ea96_row9_col6, #T_6ea96_row10_col4, #T_6ea96_row10_col6, #T_6ea96_row11_col4, #T_6ea96_row11_col6 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_6ea96_row0_col5, #T_6ea96_row1_col5, #T_6ea96_row2_col5, #T_6ea96_row3_col5, #T_6ea96_row4_col5, #T_6ea96_row5_col5, #T_6ea96_row6_col5, #T_6ea96_row7_col5, #T_6ea96_row8_col5, #T_6ea96_row9_col5, #T_6ea96_row10_col5, #T_6ea96_row11_col5 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_6ea96_row0_col7 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_6ea96_row0_col9, #T_6ea96_row1_col9, #T_6ea96_row2_col9, #T_6ea96_row3_col9, #T_6ea96_row4_col9, #T_6ea96_row5_col9, #T_6ea96_row6_col9, #T_6ea96_row7_col8, #T_6ea96_row7_col9, #T_6ea96_row8_col9, #T_6ea96_row9_col8, #T_6ea96_row9_col9, #T_6ea96_row10_col9, #T_6ea96_row11_col8, #T_6ea96_row11_col9 {
#   background-color: green;
# }
# #T_6ea96_row0_col10, #T_6ea96_row1_col10, #T_6ea96_row2_col10, #T_6ea96_row3_col10, #T_6ea96_row4_col10, #T_6ea96_row5_col10, #T_6ea96_row6_col10, #T_6ea96_row7_col10, #T_6ea96_row8_col10, #T_6ea96_row9_col10, #T_6ea96_row10_col10, #T_6ea96_row11_col10 {
#   color: red;
# }
# #T_6ea96_row0_col12 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_6ea96_row1_col2, #T_6ea96_row3_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_6ea96_row1_col6, #T_6ea96_row3_col4 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_6ea96_row1_col7, #T_6ea96_row2_col7, #T_6ea96_row2_col12, #T_6ea96_row3_col7, #T_6ea96_row4_col7, #T_6ea96_row4_col12, #T_6ea96_row7_col12, #T_6ea96_row9_col12, #T_6ea96_row11_col12 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6ea96_row1_col12, #T_6ea96_row3_col12 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_6ea96_row2_col2, #T_6ea96_row4_col2 {
#   background-color: #812804;
#   color: #f1f1f1;
# }
# #T_6ea96_row2_col6, #T_6ea96_row4_col4 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_6ea96_row5_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_6ea96_row5_col12 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_6ea96_row6_col7, #T_6ea96_row8_col7, #T_6ea96_row10_col7 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_6ea96_row6_col12, #T_6ea96_row7_col7, #T_6ea96_row8_col12, #T_6ea96_row9_col7, #T_6ea96_row10_col12, #T_6ea96_row11_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6ea96_row7_col2, #T_6ea96_row9_col2, #T_6ea96_row11_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_6ea96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ea96_level0_col0" class="col_heading level0 col0" >Op Type</th>
#       <th id="T_6ea96_level0_col1" class="col_heading level0 col1" >Dimension</th>
#       <th id="T_6ea96_level0_col2" class="col_heading level0 col2" >Op Intensity</th>
#       <th id="T_6ea96_level0_col3" class="col_heading level0 col3" >Num ops (MFLOP)</th>
#       <th id="T_6ea96_level0_col4" class="col_heading level0 col4" >Input_a (MB)</th>
#       <th id="T_6ea96_level0_col5" class="col_heading level0 col5" >Input_w (MB)</th>
#       <th id="T_6ea96_level0_col6" class="col_heading level0 col6" >Output (MB)</th>
#       <th id="T_6ea96_level0_col7" class="col_heading level0 col7" >Total Data (MB)</th>
#       <th id="T_6ea96_level0_col8" class="col_heading level0 col8" >Compute time (msec)</th>
#       <th id="T_6ea96_level0_col9" class="col_heading level0 col9" >Memory time (msec)</th>
#       <th id="T_6ea96_level0_col10" class="col_heading level0 col10" >Bound</th>
#       <th id="T_6ea96_level0_col11" class="col_heading level0 col11" >C/M ratio</th>
#       <th id="T_6ea96_level0_col12" class="col_heading level0 col12" >Cycles</th>
#       <th id="T_6ea96_level0_col13" class="col_heading level0 col13" >% of total time</th>
#       <th id="T_6ea96_level0_col14" class="col_heading level0 col14" >Throughput (Tflops)</th>
#       <th id="T_6ea96_level0_col15" class="col_heading level0 col15" >Compute cycle</th>
#       <th id="T_6ea96_level0_col16" class="col_heading level0 col16" >Memory cycle</th>
#       <th id="T_6ea96_level0_col17" class="col_heading level0 col17" >Latency (msec)</th>
#       <th id="T_6ea96_level0_col18" class="col_heading level0 col18" >C Effcy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ea96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ea96_row0_col0" class="data row0 col0" >GEMM</td>
#       <td id="T_6ea96_row0_col1" class="data row0 col1" >[   1 1536    1 4096]</td>
#       <td id="T_6ea96_row0_col2" class="data row0 col2" >0.999106</td>
#       <td id="T_6ea96_row0_col3" class="data row0 col3" >12.582912</td>
#       <td id="T_6ea96_row0_col4" class="data row0 col4" >0.007812</td>
#       <td id="T_6ea96_row0_col5" class="data row0 col5" >12.000000</td>
#       <td id="T_6ea96_row0_col6" class="data row0 col6" >0.002930</td>
#       <td id="T_6ea96_row0_col7" class="data row0 col7" >12.010742</td>
#       <td id="T_6ea96_row0_col8" class="data row0 col8" >0.000040</td>
#       <td id="T_6ea96_row0_col9" class="data row0 col9" >0.007331</td>
#       <td id="T_6ea96_row0_col10" class="data row0 col10" >M</td>
#       <td id="T_6ea96_row0_col11" class="data row0 col11" >0.005501</td>
#       <td id="T_6ea96_row0_col12" class="data row0 col12" >7330.775261</td>
#       <td id="T_6ea96_row0_col13" class="data row0 col13" >6.343269</td>
#       <td id="T_6ea96_row0_col14" class="data row0 col14" >1.716450</td>
#       <td id="T_6ea96_row0_col15" class="data row0 col15" >40.329846</td>
#       <td id="T_6ea96_row0_col16" class="data row0 col16" >7330.775261</td>
#       <td id="T_6ea96_row0_col17" class="data row0 col17" >0.007331</td>
#       <td id="T_6ea96_row0_col18" class="data row0 col18" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6ea96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ea96_row1_col0" class="data row1 col0" >Logit_MQA</td>
#       <td id="T_6ea96_row1_col1" class="data row1 col1" >[   1    8    1 1024  128    2]</td>
#       <td id="T_6ea96_row1_col2" class="data row1 col2" >3.864151</td>
#       <td id="T_6ea96_row1_col3" class="data row1 col3" >2.097152</td>
#       <td id="T_6ea96_row1_col4" class="data row1 col4" >0.001953</td>
#       <td id="T_6ea96_row1_col5" class="data row1 col5" >0.500000</td>
#       <td id="T_6ea96_row1_col6" class="data row1 col6" >0.015625</td>
#       <td id="T_6ea96_row1_col7" class="data row1 col7" >0.517578</td>
#       <td id="T_6ea96_row1_col8" class="data row1 col8" >0.000007</td>
#       <td id="T_6ea96_row1_col9" class="data row1 col9" >0.000307</td>
#       <td id="T_6ea96_row1_col10" class="data row1 col10" >M</td>
#       <td id="T_6ea96_row1_col11" class="data row1 col11" >0.021879</td>
#       <td id="T_6ea96_row1_col12" class="data row1 col12" >307.215585</td>
#       <td id="T_6ea96_row1_col13" class="data row1 col13" >0.265832</td>
#       <td id="T_6ea96_row1_col14" class="data row1 col14" >6.826320</td>
#       <td id="T_6ea96_row1_col15" class="data row1 col15" >6.721641</td>
#       <td id="T_6ea96_row1_col16" class="data row1 col16" >307.215585</td>
#       <td id="T_6ea96_row1_col17" class="data row1 col17" >0.000307</td>
#       <td id="T_6ea96_row1_col18" class="data row1 col18" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6ea96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ea96_row2_col0" class="data row2 col0" >Logit_MQA</td>
#       <td id="T_6ea96_row2_col1" class="data row2 col1" >[  1   8   1 256 128   2]</td>
#       <td id="T_6ea96_row2_col2" class="data row2 col2" >3.820896</td>
#       <td id="T_6ea96_row2_col3" class="data row2 col3" >0.524288</td>
#    MACs (MFLOP)  Total Data (MB)  Total Weights (MB)  Parameters  (MB)  \
# 0     202.37517        693.38184           692.00000         692.00000
#
#    On-chip Memory Footprint (MB)  Latency (msec)       Cycles
# 0                      168.00000         0.11557 115567.77689
# Decode Latency:4.788565338134766 msec
# single_pipe_stage:4.788565338134766 msec; single_layer_time:0.14964266681671143 msec
# Layers per pipeline stage:32
# Error = 0.051922334376109616 in latency calc. Avg Decode Latency:4.788565338134766 msec , Latency based on last token : 4.7910516730414505 msec
# Attn time:0.024634467230902776; Linear time:3.6735343933105478; AR time:1.0928828124999999; Pipeline Comm time:0.0
# {'Latency': 4.788565338134766,
#  'Throughput': 208.83081453150191,
#  'Runtime_breakdown': [3.6735343933105478,
#   0.024634467230902776,
#   1.0928828124999999],
#  'is_offload': False}

# %%
prefill_moddeling(model = 'mixtral_7x8', batch_size = 1,
                            input_tokens = 1024, output_tokens = 256, model_profilling=False,
                            tensor_parallel = 4, pipeline_parallel = 1, debug=True)
# Out:
# <style type="text/css">
# #T_61dfb_row0_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_61dfb_row0_col4 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_61dfb_row0_col5, #T_61dfb_row1_col6, #T_61dfb_row2_col4, #T_61dfb_row3_col5, #T_61dfb_row3_col6, #T_61dfb_row4_col5, #T_61dfb_row5_col5, #T_61dfb_row6_col5 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_61dfb_row0_col6, #T_61dfb_row1_col5, #T_61dfb_row2_col5, #T_61dfb_row3_col4, #T_61dfb_row4_col4, #T_61dfb_row5_col4, #T_61dfb_row6_col6 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_61dfb_row0_col7 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_61dfb_row0_col8, #T_61dfb_row1_col8, #T_61dfb_row2_col8, #T_61dfb_row3_col8, #T_61dfb_row4_col8, #T_61dfb_row5_col8, #T_61dfb_row6_col8 {
#   background-color: green;
# }
# #T_61dfb_row0_col10, #T_61dfb_row1_col10, #T_61dfb_row2_col10, #T_61dfb_row3_col10, #T_61dfb_row4_col10, #T_61dfb_row5_col10, #T_61dfb_row6_col10 {
#   color: green;
# }
# #T_61dfb_row0_col12 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_61dfb_row1_col2, #T_61dfb_row2_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_61dfb_row1_col4, #T_61dfb_row2_col6 {
#   background-color: #3585bb;
#   color: #f1f1f1;
# }
# #T_61dfb_row1_col7, #T_61dfb_row1_col12, #T_61dfb_row2_col7, #T_61dfb_row2_col12, #T_61dfb_row3_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_61dfb_row3_col2 {
#   background-color: #be3f02;
#   color: #f1f1f1;
# }
# #T_61dfb_row3_col12 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_61dfb_row4_col2, #T_61dfb_row5_col2, #T_61dfb_row6_col2 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_61dfb_row4_col6, #T_61dfb_row5_col6, #T_61dfb_row6_col4 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_61dfb_row4_col7, #T_61dfb_row4_col12, #T_61dfb_row5_col7, #T_61dfb_row5_col12, #T_61dfb_row6_col7, #T_61dfb_row6_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_61dfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61dfb_level0_col0" class="col_heading level0 col0" >Op Type</th>
#       <th id="T_61dfb_level0_col1" class="col_heading level0 col1" >Dimension</th>
#       <th id="T_61dfb_level0_col2" class="col_heading level0 col2" >Op Intensity</th>
#       <th id="T_61dfb_level0_col3" class="col_heading level0 col3" >Num ops (MFLOP)</th>
#       <th id="T_61dfb_level0_col4" class="col_heading level0 col4" >Input_a (MB)</th>
#       <th id="T_61dfb_level0_col5" class="col_heading level0 col5" >Input_w (MB)</th>
#       <th id="T_61dfb_level0_col6" class="col_heading level0 col6" >Output (MB)</th>
#       <th id="T_61dfb_level0_col7" class="col_heading level0 col7" >Total Data (MB)</th>
#       <th id="T_61dfb_level0_col8" class="col_heading level0 col8" >Compute time (msec)</th>
#       <th id="T_61dfb_level0_col9" class="col_heading level0 col9" >Memory time (msec)</th>
#       <th id="T_61dfb_level0_col10" class="col_heading level0 col10" >Bound</th>
#       <th id="T_61dfb_level0_col11" class="col_heading level0 col11" >C/M ratio</th>
#       <th id="T_61dfb_level0_col12" class="col_heading level0 col12" >Cycles</th>
#       <th id="T_61dfb_level0_col13" class="col_heading level0 col13" >% of total time</th>
#       <th id="T_61dfb_level0_col14" class="col_heading level0 col14" >Throughput (Tflops)</th>
#       <th id="T_61dfb_level0_col15" class="col_heading level0 col15" >Compute cycle</th>
#       <th id="T_61dfb_level0_col16" class="col_heading level0 col16" >Memory cycle</th>
#       <th id="T_61dfb_level0_col17" class="col_heading level0 col17" >Latency (msec)</th>
#       <th id="T_61dfb_level0_col18" class="col_heading level0 col18" >C Effcy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61dfb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61dfb_row0_col0" class="data row0 col0" >GEMM</td>
#       <td id="T_61dfb_row0_col1" class="data row0 col1" >[   1 1536 1024 4096]</td>
#       <td id="T_61dfb_row0_col2" class="data row0 col2" >534.260870</td>
#       <td id="T_61dfb_row0_col3" class="data row0 col3" >12884.901888</td>
#       <td id="T_61dfb_row0_col4" class="data row0 col4" >8.000000</td>
#       <td id="T_61dfb_row0_col5" class="data row0 col5" >12.000000</td>
#       <td id="T_61dfb_row0_col6" class="data row0 col6" >3.000000</td>
#       <td id="T_61dfb_row0_col7" class="data row0 col7" >23.000000</td>
#       <td id="T_61dfb_row0_col8" class="data row0 col8" >0.041298</td>
#       <td id="T_61dfb_row0_col9" class="data row0 col9" >0.014038</td>
#       <td id="T_61dfb_row0_col10" class="data row0 col10" >C</td>
#       <td id="T_61dfb_row0_col11" class="data row0 col11" >2.941837</td>
#       <td id="T_61dfb_row0_col12" class="data row0 col12" >41297.762462</td>
#       <td id="T_61dfb_row0_col13" class="data row0 col13" >6.250000</td>
#       <td id="T_61dfb_row0_col14" class="data row0 col14" >312.000000</td>
#       <td id="T_61dfb_row0_col15" class="data row0 col15" >41297.762462</td>
#       <td id="T_61dfb_row0_col16" class="data row0 col16" >14038.085938</td>
#       <td id="T_61dfb_row0_col17" class="data row0 col17" >0.041298</td>
#       <td id="T_61dfb_row0_col18" class="data row0 col18" >1</td>
#     </tr>
#     <tr>
#       <th id="T_61dfb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61dfb_row1_col0" class="data row1 col0" >Logit_MQA</td>
#       <td id="T_61dfb_row1_col1" class="data row1 col1" >[   1    8 1024 1024  128    2]</td>
#       <td id="T_61dfb_row1_col2" class="data row1 col2" >110.702703</td>
#       <td id="T_61dfb_row1_col3" class="data row1 col3" >2147.483648</td>
#       <td id="T_61dfb_row1_col4" class="data row1 col4" >2.000000</td>
#       <td id="T_61dfb_row1_col5" class="data row1 col5" >0.500000</td>
#       <td id="T_61dfb_row1_col6" class="data row1 col6" >16.000000</td>
#       <td id="T_61dfb_row1_col7" class="data row1 col7" >18.500000</td>
#       <td id="T_61dfb_row1_col8" class="data row1 col8" >0.006883</td>
#       <td id="T_61dfb_row1_col9" class="data row1 col9" >0.002394</td>
#       <td id="T_61dfb_row1_col10" class="data row1 col10" >C</td>
#       <td id="T_61dfb_row1_col11" class="data row1 col11" >2.875167</td>
#       <td id="T_61dfb_row1_col12" class="data row1 col12" >6882.960410</td>
#       <td id="T_61dfb_row1_col13" class="data row1 col13" >1.041667</td>
#       <td id="T_61dfb_row1_col14" class="data row1 col14" >312.000000</td>
#       <td id="T_61dfb_row1_col15" class="data row1 col15" >6882.960410</td>
#       <td id="T_61dfb_row1_col16" class="data row1 col16" >2393.934462</td>
#       <td id="T_61dfb_row1_col17" class="data row1 col17" >0.006883</td>
#       <td id="T_61dfb_row1_col18" class="data row1 col18" >1</td>
#     </tr>
#     <tr>
#       <th id="T_61dfb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61dfb_row2_col0" class="data row2 col0" >Attend_MQA</td>
#       <td id="T_61dfb_row2_col1" class="data row2 col1" >[   1    8 1024 1024  128    2]</td>
#       <td id="T_61dfb_row2_col2" class="data row2 col2" >110.702703</td>
#       <td id="T_61dfb_row2_col3" class="data row2 col3" >2147.483648</td>
#       <td id="T_61dfb_row2_col4" class="data row2 col4" >16.000000</td>
#       <td id="T_61dfb_row2_col5" class="data row2 col5" >0.500000</td>
#       <td id="T_61dfb_row2_col6" class="data row2 col6" >2.000000</td>
#       <td id="T_61dfb_row2_col7" class="data row2 col7" >18.500000</td>
#       <td id="T_61dfb_row2_col8" class="data row2 col8" >0.006883</td>
#       <td id="T_61dfb_row2_col9" class="data row2 col9" >0.002394</td>
#       <td id="T_61dfb_row2_col10" class="data row2 col10" >C</td>
#       <td id="T_61dfb_row2_col11" class="data row2 col11" >2.875167</td>
#       <td id="T_61dfb_row2_col12" class="data row2 col12" >6882.960410</td>
#       <td id="T_61dfb_row2_col13" class="data row2 col13" >1.041667</td>
#       <td id="T_61dfb_row2_col14" class="data row2 col14" >312.000000</td>
#       <td id="T_61dfb_row2_col15" class="data row2 col15" >6882.960410</td>
#       <td id="T_61dfb_row2_col16" class="data row2 col16" >2393.934462</td>
#       <
#    MACs (MFLOP)  Total Data (MB)  Total Weights (MB)  Parameters  (MB)  \
# 0  206158.43021        798.00000           692.00000         692.00000
#
#    On-chip Memory Footprint (MB)  Latency (msec)       Cycles
# 0                      240.00000         0.66076 660764.19938
# Prefill Latency:27.232454380307693 msec
# single_pipe_stage:27.232454380307693  msec; single_layer_time:0.8510141993846154  msec
# Layers per pipeline stage:32
# Error = 0.0 in latency calc. Prefill Latency:27.232454380307693 msec , Latency based on last token : 27.232454380307693 msec
# Attn time:0.44050946625641024; Linear time:20.70394491405128; AR time:6.088; Pipeline Comm time:0.0
# {'Latency': 27.232454380307693,
#  'Throughput': 36.72089140533433,
#  'Runtime_breakdown': [20.70394491405128, 0.44050946625641024, 6.088],
#  'is_offload': False}
