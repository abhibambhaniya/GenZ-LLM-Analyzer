# %%
from GenZ import get_model_df, get_summary_table, System, create_inference_moe_prefill_layer, create_inference_moe_decode_layer

import os
import pandas as pd

# %%
import os
import pandas as pd

def test_dense_LLM_prefill():
    # Delete the current CSV file if it exists
    if os.path.exists('/tmp/current_llama2_7b_prefill_on_TPU.csv'):
        os.remove('/tmp/current_llama2_7b_prefill_on_TPU.csv')

    # Generate the current result
    TPU = System(flops=300, offchip_mem_bw=1200, compute_efficiency=0.8, memory_efficiency=0.8, bits='bf16')

    # Save the current result to a CSV file
    current_df = get_model_df(model=create_inference_moe_prefill_layer(1024, "llama2_7b"), system=TPU)
    current_df.to_csv('/tmp/current_llama2_7b_prefill_on_TPU.csv', index=False)


def test_dense_LLM_decode():
    # Delete the current CSV file if it exists
    if os.path.exists('/tmp/current_llama2_7b_decode_on_TPU.csv'):
        os.remove('/tmp/current_llama2_7b_decode_on_TPU.csv')


    # Generate the current result
    TPU = System(flops=300, offchip_mem_bw=1200, compute_efficiency=0.8, memory_efficiency=0.8, bits='bf16')

    # Save the current result to a CSV file
    current_df = get_model_df(model=create_inference_moe_decode_layer(1024, "llama2_7b"), system=TPU)
    current_df.to_csv('/tmp/current_llama2_7b_decode_on_TPU.csv', index=False)

    # Reload the saved current result
    reloaded_current_df = pd.read_csv('/tmp/current_llama2_7b_decode_on_TPU.csv')


def test_moe_LLM_prefill():
    # Delete the current CSV file if it exists
    if os.path.exists('/tmp/current_mixtral_8x7b_prefill_on_GH200.csv'):
        os.remove('/tmp/current_mixtral_8x7b_prefill_on_GH200.csv')


    # Generate the current result
    GH200 = System(flops=2000, offchip_mem_bw=4900, compute_efficiency=0.8, memory_efficiency=0.8, bits='bf16',
                off_chip_mem_size=144)

    # Save the current result to a CSV file
    current_df = get_model_df(model=create_inference_moe_prefill_layer(1024, "mixtral_8x7b"), system=GH200)
    current_df.to_csv('/tmp/current_mixtral_8x7b_prefill_on_GH200.csv', index=False)



def test_moe_LLM_decode():
    # Delete the current CSV file if it exists
    if os.path.exists('/tmp/current_mixtral_8x7b_decode_on_GH200.csv'):
        os.remove('/tmp/current_mixtral_8x7b_decode_on_GH200.csv')

    # Generate the current result
    GH200 = System(flops=2000, offchip_mem_bw=4900, compute_efficiency=0.8, memory_efficiency=0.8, bits='bf16',
                off_chip_mem_size=144)

    # Save the current result to a CSV file
    current_df = get_model_df(model=create_inference_moe_decode_layer(1024, "mixtral_8x7b"), system=GH200)
    current_df.to_csv('/tmp/current_mixtral_8x7b_decode_on_GH200.csv', index=False)

# %%
test_dense_LLM_prefill()
test_dense_LLM_decode()
test_moe_LLM_prefill()
test_moe_LLM_decode()

# %%
import numpy as np
np.__version__, pd.__version__
# Out:
# ('1.26.4', '2.2.2')

# %%
from GenZ.Models.get_language_model import get_configs, create_inference_moe_prefill_layer, create_inference_moe_decode_layer

MODEL_PATH = "/tmp/genz/data/model"

# %%
file_name = create_inference_moe_prefill_layer(input_sequence_length=10, name='gpt-2')
assert file_name.endswith('.csv')
assert 'gpt-2_prefix' in file_name
df = pd.read_csv(os.path.join(MODEL_PATH, file_name), header=None)

# %%
df
# Out:
#       0   1     2   3   4  5  6
# 0     M   N     D   H   Z  Z  T
# 1  2304  10   768   1   1  0  3
# 2    12  10    10  64  12  3  4
# 3    12  10    10  64  12  1  5
# 4   768  10   768   1   1  0  3
# 5  3072  10   768   1   1  0  3
# 6   768  10  3072   1   1  0  3

# %%
from GenZ import prefill_moddeling, get_model_df, get_configs, System, create_inference_moe_prefill_layer, get_AR_time

TPU = System(flops=300, offchip_mem_bw=1200, compute_efficiency=0.8, memory_efficiency=0.8, bits='bf16',
            interchip_mem_bw=50, interchip_link_latency=1)
Model = 'gpt-2'
# Save the current result to a CSV file
current_df = get_model_df(model=create_inference_moe_prefill_layer(4096, Model, tensor_parallel=4), system=TPU)

## For GPT-2, the AR message size is 6 MB (4k tokens * 2 bytes)
AR_time = get_AR_time(data = 6*2**20, num_AR_nodes = 4, system = TPU)

prefill_output = prefill_moddeling(model = Model, batch_size = 1, input_tokens = 4096,
                            system_name = TPU, bits='bf16', tensor_parallel = 4, pipeline_parallel = 1, debug=True)
# Out:
# <style type="text/css">
# #T_fa5f6_row0_col2, #T_fa5f6_row5_col2, #T_fa5f6_row8_col2, #T_fa5f6_row9_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_fa5f6_row0_col4, #T_fa5f6_row0_col5, #T_fa5f6_row0_col6, #T_fa5f6_row1_col5, #T_fa5f6_row2_col4, #T_fa5f6_row2_col5, #T_fa5f6_row3_col5, #T_fa5f6_row3_col6, #T_fa5f6_row4_col5, #T_fa5f6_row5_col4, #T_fa5f6_row5_col5, #T_fa5f6_row5_col6, #T_fa5f6_row6_col5, #T_fa5f6_row7_col5, #T_fa5f6_row8_col4, #T_fa5f6_row8_col5, #T_fa5f6_row8_col6, #T_fa5f6_row9_col4, #T_fa5f6_row9_col5, #T_fa5f6_row9_col6 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_fa5f6_row0_col7, #T_fa5f6_row0_col13, #T_fa5f6_row5_col7, #T_fa5f6_row8_col7, #T_fa5f6_row9_col7, #T_fa5f6_row9_col13 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fa5f6_row0_col8, #T_fa5f6_row0_col9, #T_fa5f6_row0_col10, #T_fa5f6_row1_col8, #T_fa5f6_row2_col8, #T_fa5f6_row3_col8, #T_fa5f6_row4_col9, #T_fa5f6_row5_col10, #T_fa5f6_row6_col8, #T_fa5f6_row7_col8, #T_fa5f6_row8_col10, #T_fa5f6_row9_col8, #T_fa5f6_row9_col9, #T_fa5f6_row9_col10 {
#   background-color: green;
# }
# #T_fa5f6_row0_col11, #T_fa5f6_row5_col11, #T_fa5f6_row8_col11, #T_fa5f6_row9_col11 {
#   color: blue;
# }
# #T_fa5f6_row1_col2 {
#   background-color: #a83703;
#   color: #f1f1f1;
# }
# #T_fa5f6_row1_col4, #T_fa5f6_row2_col6, #T_fa5f6_row3_col4, #T_fa5f6_row4_col6, #T_fa5f6_row6_col4, #T_fa5f6_row6_col6, #T_fa5f6_row7_col4, #T_fa5f6_row7_col6 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_fa5f6_row1_col6 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_fa5f6_row1_col7 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_fa5f6_row1_col11, #T_fa5f6_row2_col11, #T_fa5f6_row3_col11, #T_fa5f6_row6_col11, #T_fa5f6_row7_col11 {
#   color: green;
# }
# #T_fa5f6_row1_col13, #T_fa5f6_row4_col7 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_fa5f6_row2_col2, #T_fa5f6_row3_col2 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_fa5f6_row2_col7, #T_fa5f6_row3_col7, #T_fa5f6_row5_col13, #T_fa5f6_row8_col13 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fa5f6_row2_col13, #T_fa5f6_row3_col13 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_fa5f6_row4_col2 {
#   background-color: #fda25a;
#   color: #000000;
# }
# #T_fa5f6_row4_col4 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_fa5f6_row4_col11 {
#   color: red;
# }
# #T_fa5f6_row4_col13 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_fa5f6_row6_col2, #T_fa5f6_row7_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_fa5f6_row6_col7, #T_fa5f6_row7_col7 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_fa5f6_row6_col13, #T_fa5f6_row7_col13 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# </style>
# <table id="T_fa5f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa5f6_level0_col0" class="col_heading level0 col0" >Op Type</th>
#       <th id="T_fa5f6_level0_col1" class="col_heading level0 col1" >Dimension</th>
#       <th id="T_fa5f6_level0_col2" class="col_heading level0 col2" >Op Intensity</th>
#       <th id="T_fa5f6_level0_col3" class="col_heading level0 col3" >Num ops (MFLOP)</th>
#       <th id="T_fa5f6_level0_col4" class="col_heading level0 col4" >Input_a (MB)</th>
#       <th id="T_fa5f6_level0_col5" class="col_heading level0 col5" >Input_w (MB)</th>
#       <th id="T_fa5f6_level0_col6" class="col_heading level0 col6" >Output (MB)</th>
#       <th id="T_fa5f6_level0_col7" class="col_heading level0 col7" >Total Data (MB)</th>
#       <th id="T_fa5f6_level0_col8" class="col_heading level0 col8" >Compute time (msec)</th>
#       <th id="T_fa5f6_level0_col9" class="col_heading level0 col9" >Memory time (msec)</th>
#       <th id="T_fa5f6_level0_col10" class="col_heading level0 col10" >Communication time (msec)</th>
#       <th id="T_fa5f6_level0_col11" class="col_heading level0 col11" >Bound</th>
#       <th id="T_fa5f6_level0_col12" class="col_heading level0 col12" >C/M ratio</th>
#       <th id="T_fa5f6_level0_col13" class="col_heading level0 col13" >Cycles</th>
#       <th id="T_fa5f6_level0_col14" class="col_heading level0 col14" >% of total time</th>
#       <th id="T_fa5f6_level0_col15" class="col_heading level0 col15" >Throughput (Tflops)</th>
#       <th id="T_fa5f6_level0_col16" class="col_heading level0 col16" >Compute cycle</th>
#       <th id="T_fa5f6_level0_col17" class="col_heading level0 col17" >Memory cycle</th>
#       <th id="T_fa5f6_level0_col18" class="col_heading level0 col18" >Latency (msec)</th>
#       <th id="T_fa5f6_level0_col19" class="col_heading level0 col19" >C Effcy</th>
#       <th id="T_fa5f6_level0_col20" class="col_heading level0 col20" >Communication cycle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa5f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa5f6_row0_col0" class="data row0 col0" >Repeat</td>
#       <td id="T_fa5f6_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_fa5f6_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_fa5f6_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_fa5f6_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_fa5f6_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_fa5f6_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_fa5f6_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_fa5f6_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_fa5f6_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_fa5f6_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_fa5f6_row0_col11" class="data row0 col11" >Collective</td>
#       <td id="T_fa5f6_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_fa5f6_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_fa5f6_row0_col14" class="data row0 col14" >0.000000</td>
#       <td id="T_fa5f6_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_fa5f6_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_fa5f6_row0_col17" class="data row0 col17" >0.000000</td>
#       <td id="T_fa5f6_row0_col18" class="data row0 col18" >0.000000</td>
#       <td id="T_fa5f6_row0_col19" class="data row0 col19" >0.800000</td>
#       <td id="T_fa5f6_row0_col20" class="data row0 col20" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa5f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa5f6_row1_col0" class="data row1 col0" >GEMM</td>
#       <td id="T_fa5f6_row1_col1" class="data row1 col1" >[((1, 768, 4096), (576, 768), (1, 576, 4096))]</td>
#       <td id="T_fa5f6_row1_col2" class="data row1 col2" >304.661157</td>
#       <td id="T_fa5f6_row1_col3" class="data row1 col3" >3623.878656</td>
#       <td id="T_fa5f6_row1_col4" class="data row1 col4" >6.000000</td>
#       <td id="T_fa5f6_row1_col5" class="data row1 col5" >0.843750</td>
#       <td id="T_fa5f6_row1_col6" class="data row1 col6" >4.500000</td>
#       <td id="T_fa5f6_row1_col7" class="data row1 col7" >11.343750</td>
#       <td id="T_fa5f6_row1_col8" class="data row1 col8" >0.015099</td>
#       <td id="T_fa5f6_row1_col9" class="data row1 col9" >0.011539</td>
#       <td id="T_fa5f6_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_fa5f6_row1_col11" class="data row1 col11" >Compute</td>
#       <td id="T_fa5f6_row1_col12" class="data row1 col12" >1.308510</td>
#       <td id="T_fa5f6_row1_col13" class="data row1 col13" >14193.524736</td>
#       <td id="T_fa5f6_row1_col14" class="data row1 col14" >3.078201</td>
#       <td id="T_fa5f6_row1_col15" class="data row1 col15" >240.000000</td>
#       <td id="T_fa5f6_row1_col16" class="data row1 col16" >14193.524736</td>
#       <td id="T_fa5f6_row1_col17" class="data row1 col17" >10847.091675</td>
#       <td id="T_fa5f6_row1_col18" class="data row1 col18" >0.015099</td>
#       <td id="T_fa5f6_row1_col19" class="data row1 col19" >0.800000</td>
#       <td id="T_fa5f6_row1_col20" class="data row1 col20" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa5f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa5f6_row2_col0"
#    MACs (MFLOP)  Total Data (MB)  Total Weights (MB)  Unused Weights (MB)  \
# 0  328564.99814       2920.50000            40.50000              0.00000
#
#    KV Cache (MB)  On-chip Memory Footprint (MB)  Latency (msec)        Cycles  \
# 0       36.00000                       99.00000         5.88636 5533177.28132
#
#    Attn Latency (msec)  Linear Latency (msec)  Comm Latency (msec)
# 0              0.64425                0.75936              4.48275

# %%
prefill_output
# Out:
# {'Latency': 5.886358809914062,
#  'Throughput': 169.88430917866518,
#  'Runtime_breakdown': [0.7593637155140625, 0.6442450944, 4.482749999999999],
#  'is_offload': False}

# %%
get_AR_time(data = 6*2**20, num_AR_nodes = 4, system = TPU)
# Out:
# 0.18678124999999998

# %%
TPU.interchip_link_latency
# Out:
# 1e-06

# %%
import numpy as np
np.isclose([5.886358809914062, 169.88430917866518, 0.7593637155140625],
            [5.888638473, 169.8185420255, 0.7616433786,])
# Out:
# array([False, False, False])
